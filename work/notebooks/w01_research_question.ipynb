# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## My Lane
#
# I chose **Lane 1: Content Performance Prediction** because businesses publish many webpages but cannot optimize every page at once. My goal is to use the available data to identify patterns that help prioritize which pages should be improved first. This project supports SEO and content decisions using data rather than replacing human judgment.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## The Question
#
# **Research Question:** Which webpages should be optimized first to improve SEO performance?
#
# **Decision:** The SEO or content team decides which webpages to prioritize for optimization.
#
# **Action:** Update page content, improve keywords, optimize titles and meta descriptions, and add internal links to the selected pages.
#
# **Cost of a Wrong Recommendation:** If a high-performing page is selected unnecessarily, time and resources are wasted. If a low-performing page is ignored, the website may lose potential organic traffic and business opportunities.
#
# **Why Data or ML Helps:** When there are many webpages, manually reviewing each page is difficult. Data analysis and machine learning can identify useful patterns that support better decision-making.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
import zipfile
import os

# Define the path to your zip file and the directory to extract to
zip_file_path = '/content/flyrank-ml-internship-starter-main.zip'
extract_dir = '/content/data'

# Create the extraction directory if it doesn't exist
if not os.path.exists(extract_dir):
    os.makedirs(extract_dir)

# Unzip the file if the extraction directory is empty or doesn't exist yet
# This prevents re-unzipping if already done, but forces it if the folder is gone
if not os.listdir(extract_dir):
    print(f"Unzipping {zip_file_path} to {extract_dir}...")
    with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
        zip_ref.extractall(extract_dir)
    print("Extraction complete. Listing contents:")
    for root, dirs, files in os.walk(extract_dir):
        for file in files:
            print(os.path.join(root, file))
else:
    print(f"Directory {extract_dir} already exists and is not empty. Skipping extraction.")
    print("Contents of existing data directory:")
    for root, dirs, files in os.walk(extract_dir):
        for file in files:
            print(os.path.join(root, file))

# TODO: Replace "YOUR_CSV_FILE.csv" with the actual path to your CSV file
# For example, if your CSV is in /content/data/my_file.csv, use:
# df = pd.read_csv(os.path.join(extract_dir, "my_file.csv"))
# If it's deeper, like /content/data/subfolder/my_file.csv, use:
# df = pd.read_csv(os.path.join(extract_dir, "subfolder", "my_file.csv"))

df = pd.read_csv(os.path.join(extract_dir, "flyrank-ml-internship-starter-main", "outputs", "refresh_queue_sample.csv")) # Updated to use the sample CSV file

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

df.describe()
# Out:
# Directory /content/data already exists and is not empty. Skipping extraction.
# Contents of existing data directory:
# /content/data/flyrank-ml-internship-starter-main/LICENSE
# /content/data/flyrank-ml-internship-starter-main/CLAUDE.md
# /content/data/flyrank-ml-internship-starter-main/AGENTS.md
# /content/data/flyrank-ml-internship-starter-main/requirements.txt
# /content/data/flyrank-ml-internship-starter-main/README.md
# /content/data/flyrank-ml-internship-starter-main/DATA_USE.md
# /content/data/flyrank-ml-internship-starter-main/GUIDE.md
# /content/data/flyrank-ml-internship-starter-main/.gitignore
# /content/data/flyrank-ml-internship-starter-main/SETUP.md
# /content/data/flyrank-ml-internship-starter-main/notebooks/02_your_first_readable_model.ipynb
# /content/data/flyrank-ml-internship-starter-main/notebooks/01_first_look_and_discovery.ipynb
# /content/data/flyrank-ml-internship-starter-main/notebooks/03_working_with_the_full_release.ipynb
# ...

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## What I Can and Can't Claim
#
# This project can identify observed patterns in the available data and provide decision support for SEO optimization. The results may help prioritize webpages that could benefit from improvements.
#
# This project cannot prove that one factor directly causes better search rankings, and it cannot predict Google's ranking algorithm. The findings depend on the quality and completeness of the available data.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
