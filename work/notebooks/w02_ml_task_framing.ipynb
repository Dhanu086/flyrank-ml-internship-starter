# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Dhanu086/flyrank-ml-internship-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# My lane is a classification task because the goal is to predict a category based on previous data. The model will classify each case into one of two or more groups instead of predicting a continuous number

# %%
task_type = "classification"
print("ML task:", task_type)
# Out:
# ML task: classification

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# The target is the outcome we want to predict. The label comes from an observed result collected from past data, not from an assumption. For example, customer churn can be labeled based on whether a customer actually left.

# %%
target = "customer_churn"
print("Target variable:", target)
# Out:
# Target variable: customer_churn

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# I will use accuracy as the evaluation metric because it measures how many predictions are correct. A higher accuracy score indicates better performance.

# %%
metric = "accuracy"
print("Success metric:", metric)
# Out:
# Success metric: accuracy

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# One row represents one customer record. Each row contains features such as age, usage pattern, and previous activity that help the model make predictions.

# %%
import pandas as pd

data = {
    "customer_id":[1,2,3],
    "usage":[10,20,15],
    "churn":[0,1,0]
}

df = pd.DataFrame(data)
df
# Out:
#    customer_id  usage  churn
# 0            1     10      0
# 1            2     20      1
# 2            3     15      0

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# A fixed rule cannot handle complex patterns because customer behavior depends on many factors. ML can learn patterns from historical data and improve predictions as more data becomes available

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %%
reason = "ML learns complex patterns from data"
print(reason)
# Out:
# ML learns complex patterns from data

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
